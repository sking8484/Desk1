# %%
import pandas as pd
from scipy import fft
import matplotlib.pyplot as plt
import numpy as np
data = pd.read_csv('prices.csv')

# %%
aapl = data['AAPL'].pct_change()[1:].to_list()
N = len(aapl)
spacing = 1/252
x = np.linspace(0, N*spacing, N, endpoint = False)

# %%
yf = fft.fft(aapl)

# %%
xf = fft.fftfreq(N, 1)

# %%
plt.plot(xf[:N//2], 2/N * (yf[:N//2]))
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
